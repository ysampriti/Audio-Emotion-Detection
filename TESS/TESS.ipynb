# %%
import numpy as np
import os

# %%
import librosa
import soundfile
import glob

# %%
path = "./toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data"

# %%
directory = os.listdir(path)

# %%
directory
# Out:
# ['OAF_sad',
#  'YAF_disgust',
#  'YAF_sad',
#  'OAF_Pleasant_surprise',
#  'YAF_angry',
#  'YAF_happy',
#  'OAF_neutral',
#  'OAF_fear',
#  'OAF_disgust',
#  'YAF_neutral',
#  'YAF_fear',
#  'OAF_happy',
#  'YAF_pleasant_surprise',
#  'OAF_angry']

# %%
X  = []
audios = []
labels = []

# %%
for dir_name in directory : 
    emotion = (dir_name.split('_')[-1])
    path_for_audio = path + "/" + dir_name
    directory_audios=  os.listdir(path_for_audio)
    for audio in directory_audios : 
        audio_loc = path_for_audio + "/" +  audio
        x,sr = librosa.load(audio_loc)
        audios.append(x)
        labels.append(emotion)

# %%
labels=np.asarray(labels)

# %%
labels.shape
# Out:
# (2800,)

# %%
audios=np.asarray(audios)

# %%
audios.shape
# Out:
# (2800,)

# %%
# np.save('TESS_audios.npy', audios)
# np.save('TESS_labels.npy', labels)

# %%
audios = np.load('TESS_audios.npy', allow_pickle=True)
labels = np.load('TESS_labels.npy',allow_pickle=True)

# %%
emotion_dict = {
    0 : "angry",
    1 : "disgust",
    2 : "fear",
    3 : "happy",
    4 : "neutral",
    5 : "sad",
    6 : "surprise"
}

# %%
def extract_feature(audio, mfcc, chroma, mel):
    X = audio
    sample_rate = 22050
    if chroma:
        stft=np.abs(librosa.stft(X))
        result=np.array([])
    if mfcc:
        mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
        result=np.hstack((result, mfccs))
    if chroma:
        chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
        result=np.hstack((result, chroma))
    if mel:
        mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
        result=np.hstack((result, mel))
    return result

# %%
def load_data(test_size=0.2):
    X_new,Y_new=[],[]
    idx = 0;
    for audio in audios:
#         emotion = emotion_dict[labels[idx]]
#         print(emotion)
        idx +=1
#         if emotion not in observed_emotions:
#             continue

        feature=extract_feature(audio, mfcc=True, chroma=True, mel=True)
        X_new.append(feature)
#         Y_new.append(emotion)
        
    return (X_new,Y_new)

# %%
DATA = load_data()

# %%
X_new = np.array(DATA[0])
Y_new = np.array(labels)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import KFold, cross_validate

# %%
X_new_train, X_new_test, Y_new_train, Y_new_test  = train_test_split(X_new, Y_new,test_size=0.10,random_state=3)

# %%
print((X_new_train.shape[0], X_new_test.shape[0]))
# Out:
# (2520, 280)

# %%
model=MLPClassifier(alpha=0.01, batch_size=264, epsilon=1e-08,
                    hidden_layer_sizes=(300,), learning_rate='adaptive', max_iter=700, 
                    activation='tanh',learning_rate_init=0.001, verbose=True, early_stopping=True)

# %%
cvresults=cross_validate(model, X_new_train, Y_new_train, cv=10, return_train_score=True)
# Out:
# Iteration 1, loss = 2.06346126
# Validation score: 0.246696
# Iteration 2, loss = 1.48739203
# Validation score: 0.748899
# Iteration 3, loss = 1.08100292
# Validation score: 0.788546
# Iteration 4, loss = 0.82750438
# Validation score: 0.854626
# Iteration 5, loss = 0.64131445
# Validation score: 0.903084
# Iteration 6, loss = 0.49886492
# Validation score: 0.973568
# Iteration 7, loss = 0.38901661
# Validation score: 0.982379
# Iteration 8, loss = 0.29333309
# Validation score: 0.977974
# Iteration 9, loss = 0.21992714
# Validation score: 1.000000
# Iteration 10, loss = 0.16868391
# Validation score: 1.000000
# Iteration 11, loss = 0.12946237
# Validation score: 0.995595
# Iteration 12, loss = 0.10225903
# Validation score: 1.000000
# Iteration 13, loss = 0.07972999
# Validation score: 1.000000
# Iteration 14, loss = 0.06252932
# Validation score: 1.000000
# Iteration 15, loss = 0.04979532
# Validation score: 0.995595
# Iteration 16, loss = 0.03912992
# Validation score: 1.000000
# Iteration 17, loss = 0.03302605
# Validation score: 1.000000
# Iteration 18, loss = 0.02722374
# Validation score: 1.000000
# Iteration 19, loss = 0.02361923
# Validation score: 1.000000
# Iteration 20, loss = 0.02103127
# Validation score: 1.000000
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.77540699
# Validation score: 0.616740
# Iteration 2, loss = 1.25239665
# Validation score: 0.837004
# Iteration 3, loss = 0.93370805
# Validation score: 0.881057
# Iteration 4, loss = 0.71174075
# Validation score: 0.916300
# Iteration 5, loss = 0.55765569
# Validation score: 0.920705
# Iteration 6, loss = 0.43494711
# Validation score: 0.942731
# Iteration 7, loss = 0.33182188
# Validation score: 0.960352
# Iteration 8, loss = 0.26272363
# Validation score: 0.986784
# Iteration 9, loss = 0.20806559
# Validation score: 0.991189
# Iteration 10, loss = 0.16538611
# Validation score: 0.995595
# Iteration 11, loss = 0.13483728
# Validation score: 0.995595
# Iteration 12, loss = 0.11111062
# Validation score: 0.995595
# Iteration 13, loss = 0.08754393
# Validation score: 0.995595
# Iteration 14, loss = 0.07033810
# Validation score: 0.995595
# Iteration 15, loss = 0.05767409
# Validation score: 0.995595
# Iteration 16, loss = 0.04729491
# Validation score: 0.995595
# Iteration 17, loss = 0.04041367
# Validation score: 1.000000
# Iteration 18, loss = 0.03319685
# Validation score: 1.000000
# Iteration 19, loss = 0.02777173
# Validation score: 0.995595
# Iteration 20, loss = 0.02296545
# Validation score: 1.000000
# Iteration 21, loss = 0.01976362
# Validation score: 1.000000
# Iteration 22, loss = 0.01733466
# Validation score: 1.000000
# Iteration 23, loss = 0.01613527
# Validation score: 1.000000
# Iteration 24, loss = 0.01420684
# Validation score: 1.000000
# Iteration 25, loss = 0.01322217
# Validation score: 1.000000
# Iteration 26, loss = 0.01213851
# Validation score: 1.000000
# Iteration 27, loss = 0.01087413
# Validation score: 1.000000
# Iteration 28, loss = 0.01033219
# Validation score: 1.000000
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.90208381
# Validation score: 0.449339
# Iteration 2, loss = 1.42073072
# Validation score: 0.678414
# Iteration 3, loss = 1.11394287
# Validation score: 0.810573
# Iteration 4, loss = 0.86842573
# Validation score: 0.810573
# Iteration 5, loss = 0.67542536
# Validation score: 0.876652
# Iteration 6, loss = 0.50580047
# Validation score: 0.907489
# Iteration 7, loss = 0.37379272
# Validation score: 0.955947
# Iteration 8, loss = 0.27918266
# Validation score: 0.955947
# Iteration 9, loss = 0.20893237
# Validation score: 0.951542
# Iteration 10, loss = 0.16000573
# Validation score: 0.973568
# Iteration 11, loss = 0.12435210
# Validation score: 0.982379
# Iteration 12, loss = 0.09976996
# Validation score: 0.982379
# Iteration 13, loss = 0.07813545
# Validation score: 0.977974
# Iteration 14, loss = 0.06159612
# Validation score: 0.982379
# Iteration 15, loss = 0.04852466
# Validation score: 0.977974
# Iteration 16, loss = 0.03919501
# Validation score: 0.986784
# Iteration 17, loss = 0.03226853
# Validation score: 0.986784
# Iteration 18, loss = 0.02743406
# Validation score: 0.982379
# Iteration 19, loss = 0.02292413
# Validation score: 0.991189
# Iteration 20, loss = 0.01860745
# Validation score: 0.986784
# Iteration 21, loss = 0.01736756
# Validation score: 0.991189
# Iteration 22, loss = 0.01490873
# Validation score: 0.995595
# Iteration 23, loss = 0.01342074
# Validation score: 1.000000
# Iteration 24, loss = 0.01161794
# Validation score: 0.995595
# Iteration 25, loss = 0.01053701
# Validation score: 0.991189
# Iteration 26, loss = 0.01077014
# Validation score: 1.000000
# Iteration 27, loss = 0.01000635
# Validation score: 0.995595
# Iteration 28, loss = 0.00914432
# Validation score: 0.991189
# Iteration 29, loss = 0.00798715
# Validation score: 1.000000
# Iteration 30, loss = 0.00764671
# Validation score: 0.991189
# Iteration 31, loss = 0.00704973
# Validation score: 1.000000
# Iteration 32, loss = 0.00672826
# Validation score: 0.991189
# Iteration 33, loss = 0.00629653
# Validation score: 1.000000
# Iteration 34, loss = 0.00611552
# Validation score: 0.991189
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.81454706
# Validation score: 0.581498
# Iteration 2, loss = 1.35631544
# Validation score: 0.766520
# Iteration 3, loss = 1.05508314
# Validation score: 0.841410
# Iteration 4, loss = 0.81575783
# Validation score: 0.881057
# Iteration 5, loss = 0.62520818
# Validation score: 0.925110
# Iteration 6, loss = 0.46626784
# Validation score: 0.942731
# Iteration 7, loss = 0.35192229
# Validation score: 0.942731
# Iteration 8, loss = 0.27040195
# Validation score: 0.960352
# Iteration 9, loss = 0.21049646
# Validation score: 0.955947
# Iteration 10, loss = 0.16104798
# Validation score: 0.964758
# Iteration 11, loss = 0.12603996
# Validation score: 0.969163
# Iteration 12, loss = 0.09612621
# Validation score: 0.977974
# Iteration 13, loss = 0.07440347
# Validation score: 0.982379
# Iteration 14, loss = 0.05966865
# Validation score: 0.986784
# Iteration 15, loss = 0.04929378
# Validation score: 0.986784
# Iteration 16, loss = 0.04080160
# Validation score: 0.991189
# Iteration 17, loss = 0.03380657
# Validation score: 0.986784
# Iteration 18, loss = 0.02821509
# Validation score: 0.991189
# Iteration 19, loss = 0.02532757
# Validation score: 0.991189
# Iteration 20, loss = 0.02078444
# Validation score: 0.991189
# Iteration 21, loss = 0.01809789
# Validation score: 0.986784
# Iteration 22, loss = 0.01553201
# Validation score: 0.995595
# Iteration 23, loss = 0.01395644
# Validation score: 0.991189
# Iteration 24, loss = 0.01243730
# Validation score: 0.995595
# Iteration 25, loss = 0.01150891
# Validation score: 0.995595
# Iteration 26, loss = 0.01050171
# Validation score: 0.995595
# Iteration 27, loss = 0.00976599
# Validation score: 0.995595
# Iteration 28, loss = 0.00892355
# Validation score: 0.995595
# Iteration 29, loss = 0.00859420
# Validation score: 0.995595
# Iteration 30, loss = 0.00855720
# Validation score: 0.995595
# Iteration 31, loss = 0.00792749
# Validation score: 0.995595
# Iteration 32, loss = 0.00762455
# Validation score: 0.995595
# Iteration 33, loss = 0.00712178
# Validation score: 0.991189
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 2.05062974
# Validation score: 0.383260
# Iteration 2, loss = 1.59549450
# Validation score: 0.590308
# Iteration 3, loss = 1.34609592
# Validation score: 0.762115
# Iteration 4, loss = 1.11075155
# Validation score: 0.832599
# Iteration 5, loss = 0.90672881
# Validation score: 0.859031
# Iteration 6, loss = 0.72263294
# Validation score: 0.920705
# Iteration 7, loss = 0.55459173
# Validation score: 0.942731
# Iteration 8, loss = 0.41354820
# Validation score: 0.947137
# Iteration 9, loss = 0.29765150
# Validation score: 0.960352
# Iteration 10, loss = 0.21538556
# Validation score: 0.960352
# Iteration 11, loss = 0.16314086
# Validation score: 0.964758
# Iteration 12, loss = 0.12403218
# Validation score: 0.969163
# Iteration 13, loss = 0.09530612
# Validation score: 0.973568
# Iteration 14, loss = 0.07442508
# Validation score: 0.973568
# Iteration 15, loss = 0.05895282
# Validation score: 0.973568
# Iteration 16, loss = 0.04577401
# Validation score: 0.977974
# Iteration 17, loss = 0.03657057
# Validation score: 0.982379
# Iteration 18, loss = 0.03080566
# Validation score: 0.982379
# Iteration 19, loss = 0.02509863
# Validation score: 0.982379
# Iteration 20, loss = 0.02079608
# Validation score: 0.986784
# Iteration 21, loss = 0.01771974
# Validation score: 0.986784
# Iteration 22, loss = 0.01665342
# Validation score: 0.986784
# Iteration 23, loss = 0.01397542
# Validation score: 0.991189
# Iteration 24, loss = 0.01248608
# Validation score: 0.986784
# Iteration 25, loss = 0.01094943
# Validation score: 0.986784
# Iteration 26, loss = 0.00988471
# Validation score: 0.995595
# Iteration 27, loss = 0.00933399
# Validation score: 0.991189
# Iteration 28, loss = 0.00844110
# Validation score: 0.991189
# Iteration 29, loss = 0.00881231
# Validation score: 0.995595
# Iteration 30, loss = 0.00745516
# Validation score: 0.995595
# Iteration 31, loss = 0.00699434
# Validation score: 0.991189
# Iteration 32, loss = 0.00660368
# Validation score: 0.991189
# Iteration 33, loss = 0.00627602
# Validation score: 0.995595
# Iteration 34, loss = 0.00606822
# Validation score: 0.995595
# Iteration 35, loss = 0.00585695
# Validation score: 0.995595
# Iteration 36, loss = 0.00554295
# Validation score: 0.995595
# Iteration 37, loss = 0.00530120
# Validation score: 0.995595
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.94027871
# Validation score: 0.339207
# Iteration 2, loss = 1.50232668
# Validation score: 0.700441
# Iteration 3, loss = 1.19444372
# Validation score: 0.814978
# Iteration 4, loss = 0.93999229
# Validation score: 0.872247
# Iteration 5, loss = 0.73218246
# Validation score: 0.947137
# Iteration 6, loss = 0.56498899
# Validation score: 0.947137
# Iteration 7, loss = 0.43651382
# Validation score: 0.969163
# Iteration 8, loss = 0.33679819
# Validation score: 0.973568
# Iteration 9, loss = 0.26751416
# Validation score: 0.986784
# Iteration 10, loss = 0.21055435
# Validation score: 0.995595
# Iteration 11, loss = 0.16289092
# Validation score: 0.991189
# Iteration 12, loss = 0.12258565
# Validation score: 0.991189
# Iteration 13, loss = 0.09623952
# Validation score: 0.995595
# Iteration 14, loss = 0.07624815
# Validation score: 1.000000
# Iteration 15, loss = 0.06066703
# Validation score: 0.991189
# Iteration 16, loss = 0.04886981
# Validation score: 0.995595
# Iteration 17, loss = 0.04068058
# Validation score: 0.995595
# Iteration 18, loss = 0.03315520
# Validation score: 1.000000
# Iteration 19, loss = 0.02701120
# Validation score: 0.995595
# Iteration 20, loss = 0.02222260
# Validation score: 0.995595
# Iteration 21, loss = 0.02150195
# Validation score: 1.000000
# Iteration 22, loss = 0.01867303
# Validation score: 1.000000
# Iteration 23, loss = 0.01573487
# Validation score: 1.000000
# Iteration 24, loss = 0.01429183
# Validation score: 1.000000
# Iteration 25, loss = 0.01337042
# Validation score: 1.000000
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.86494991
# Validation score: 0.502203
# Iteration 2, loss = 1.35950092
# Validation score: 0.744493
# Iteration 3, loss = 1.03957882
# Validation score: 0.797357
# Iteration 4, loss = 0.78952112
# Validation score: 0.841410
# Iteration 5, loss = 0.61775183
# Validation score: 0.881057
# Iteration 6, loss = 0.48113434
# Validation score: 0.942731
# Iteration 7, loss = 0.36790744
# Validation score: 0.947137
# Iteration 8, loss = 0.28462461
# Validation score: 0.977974
# Iteration 9, loss = 0.21757245
# Validation score: 0.977974
# Iteration 10, loss = 0.16574472
# Validation score: 0.977974
# Iteration 11, loss = 0.12853217
# Validation score: 0.982379
# Iteration 12, loss = 0.10096363
# Validation score: 0.982379
# Iteration 13, loss = 0.07903192
# Validation score: 0.982379
# Iteration 14, loss = 0.06263856
# Validation score: 0.986784
# Iteration 15, loss = 0.05002226
# Validation score: 0.995595
# Iteration 16, loss = 0.04012683
# Validation score: 0.995595
# Iteration 17, loss = 0.03215263
# Validation score: 0.991189
# Iteration 18, loss = 0.02548067
# Validation score: 0.991189
# Iteration 19, loss = 0.02146099
# Validation score: 0.991189
# Iteration 20, loss = 0.01791528
# Validation score: 0.991189
# Iteration 21, loss = 0.01512893
# Validation score: 0.991189
# Iteration 22, loss = 0.01348504
# Validation score: 0.991189
# Iteration 23, loss = 0.01231022
# Validation score: 0.991189
# Iteration 24, loss = 0.01124688
# Validation score: 0.991189
# Iteration 25, loss = 0.01021359
# Validation score: 0.991189
# Iteration 26, loss = 0.00929592
# Validation score: 0.991189
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.93819247
# Validation score: 0.374449
# Iteration 2, loss = 1.40943649
# Validation score: 0.643172
# Iteration 3, loss = 1.05133635
# Validation score: 0.819383
# Iteration 4, loss = 0.81594397
# Validation score: 0.859031
# Iteration 5, loss = 0.62743953
# Validation score: 0.933921
# Iteration 6, loss = 0.48230160
# Validation score: 0.969163
# Iteration 7, loss = 0.37228437
# Validation score: 0.964758
# Iteration 8, loss = 0.28629764
# Validation score: 0.964758
# Iteration 9, loss = 0.21972849
# Validation score: 0.973568
# Iteration 10, loss = 0.16821096
# Validation score: 0.969163
# Iteration 11, loss = 0.12673366
# Validation score: 0.986784
# Iteration 12, loss = 0.10072462
# Validation score: 0.982379
# Iteration 13, loss = 0.07946075
# Validation score: 0.973568
# Iteration 14, loss = 0.06592573
# Validation score: 0.991189
# Iteration 15, loss = 0.05279110
# Validation score: 0.986784
# Iteration 16, loss = 0.04553016
# Validation score: 0.986784
# Iteration 17, loss = 0.03650835
# Validation score: 0.986784
# Iteration 18, loss = 0.02914388
# Validation score: 0.986784
# Iteration 19, loss = 0.02397868
# Validation score: 0.995595
# Iteration 20, loss = 0.02010899
# Validation score: 0.986784
# Iteration 21, loss = 0.01761570
# Validation score: 0.986784
# Iteration 22, loss = 0.01601999
# Validation score: 0.995595
# Iteration 23, loss = 0.01393952
# Validation score: 0.995595
# Iteration 24, loss = 0.01245124
# Validation score: 0.991189
# Iteration 25, loss = 0.01127607
# Validation score: 0.995595
# Iteration 26, loss = 0.01038907
# Validation score: 0.995595
# Iteration 27, loss = 0.00962149
# Validation score: 0.995595
# Iteration 28, loss = 0.00957745
# Validation score: 1.000000
# Iteration 29, loss = 0.00892876
# Validation score: 1.000000
# Iteration 30, loss = 0.00833645
# Validation score: 0.995595
# Iteration 31, loss = 0.00763022
# Validation score: 1.000000
# Iteration 32, loss = 0.00726394
# Validation score: 1.000000
# Iteration 33, loss = 0.00675908
# Validation score: 1.000000
# Iteration 34, loss = 0.00649438
# Validation score: 1.000000
# Iteration 35, loss = 0.00622011
# Validation score: 1.000000
# Iteration 36, loss = 0.00611207
# Validation score: 1.000000
# Iteration 37, loss = 0.00606066
# Validation score: 1.000000
# Iteration 38, loss = 0.00583075
# Validation score: 0.995595
# Iteration 39, loss = 0.00574121
# Validation score: 1.000000
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.96594156
# Validation score: 0.453744
# Iteration 2, loss = 1.42243863
# Validation score: 0.722467
# Iteration 3, loss = 1.09356716
# Validation score: 0.770925
# Iteration 4, loss = 0.85175791
# Validation score: 0.867841
# Iteration 5, loss = 0.66366334
# Validation score: 0.929515
# Iteration 6, loss = 0.52408255
# Validation score: 0.964758
# Iteration 7, loss = 0.41086219
# Validation score: 0.960352
# Iteration 8, loss = 0.31716722
# Validation score: 0.982379
# Iteration 9, loss = 0.24267427
# Validation score: 0.964758
# Iteration 10, loss = 0.18426233
# Validation score: 0.973568
# Iteration 11, loss = 0.14112991
# Validation score: 0.977974
# Iteration 12, loss = 0.10644982
# Validation score: 0.986784
# Iteration 13, loss = 0.08210758
# Validation score: 0.977974
# Iteration 14, loss = 0.06574414
# Validation score: 0.986784
# Iteration 15, loss = 0.05319679
# Validation score: 0.995595
# Iteration 16, loss = 0.04246616
# Validation score: 0.995595
# Iteration 17, loss = 0.03477084
# Validation score: 0.982379
# Iteration 18, loss = 0.02955601
# Validation score: 0.995595
# Iteration 19, loss = 0.02421553
# Validation score: 0.991189
# Iteration 20, loss = 0.01961605
# Validation score: 0.991189
# Iteration 21, loss = 0.01711186
# Validation score: 0.991189
# Iteration 22, loss = 0.01468975
# Validation score: 0.991189
# Iteration 23, loss = 0.01322739
# Validation score: 0.991189
# Iteration 24, loss = 0.01183861
# Validation score: 0.991189
# Iteration 25, loss = 0.01064363
# Validation score: 0.995595
# Iteration 26, loss = 0.01010951
# Validation score: 0.991189
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.72210401
# Validation score: 0.471366
# Iteration 2, loss = 1.33242346
# Validation score: 0.748899
# Iteration 3, loss = 1.07064698
# Validation score: 0.819383
# Iteration 4, loss = 0.84487729
# Validation score: 0.828194
# Iteration 5, loss = 0.66586812
# Validation score: 0.881057
# Iteration 6, loss = 0.52449303
# Validation score: 0.933921
# Iteration 7, loss = 0.40173725
# Validation score: 0.973568
# Iteration 8, loss = 0.30458858
# Validation score: 0.977974
# Iteration 9, loss = 0.23368815
# Validation score: 0.986784
# Iteration 10, loss = 0.17895399
# Validation score: 0.986784
# Iteration 11, loss = 0.13366063
# Validation score: 0.982379
# Iteration 12, loss = 0.09868352
# Validation score: 0.991189
# Iteration 13, loss = 0.07631197
# Validation score: 0.991189
# Iteration 14, loss = 0.06008609
# Validation score: 0.991189
# Iteration 15, loss = 0.04807556
# Validation score: 0.991189
# Iteration 16, loss = 0.03979966
# Validation score: 0.991189
# Iteration 17, loss = 0.03674605
# Validation score: 0.991189
# Iteration 18, loss = 0.02951703
# Validation score: 0.991189
# Iteration 19, loss = 0.02609328
# Validation score: 0.991189
# Iteration 20, loss = 0.02214156
# Validation score: 0.995595
# Iteration 21, loss = 0.01930058
# Validation score: 0.991189
# Iteration 22, loss = 0.01715116
# Validation score: 1.000000
# Iteration 23, loss = 0.01536160
# Validation score: 1.000000
# Iteration 24, loss = 0.01377120
# Validation score: 0.995595
# Iteration 25, loss = 0.01327288
# Validation score: 1.000000
# Iteration 26, loss = 0.01160213
# Validation score: 1.000000
# Iteration 27, loss = 0.01062755
# Validation score: 1.000000
# Iteration 28, loss = 0.00976392
# Validation score: 1.000000
# Iteration 29, loss = 0.00911326
# Validation score: 1.000000
# Iteration 30, loss = 0.00877469
# Validation score: 1.000000
# Iteration 31, loss = 0.00862795
# Validation score: 1.000000
# Iteration 32, loss = 0.00778429
# Validation score: 1.000000
# Iteration 33, loss = 0.00715828
# Validation score: 1.000000
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
cvresults
# Out:
# {'fit_time': array([2.43099666, 3.06758952, 3.89309216, 3.58353281, 3.91978693,
#         3.25590992, 2.10922766, 2.96107459, 2.70141983, 2.64397192]),
#  'score_time': array([0.00683379, 0.01501417, 0.02613616, 0.00625968, 0.01269102,
#         0.00679255, 0.00597191, 0.0059135 , 0.00625181, 0.00534225]),
#  'test_score': array([0.98832685, 0.99215686, 1.        , 1.        , 0.98804781,
#         0.99203187, 0.98804781, 1.        , 0.988     , 0.992     ]),
#  'train_score': array([0.98895272, 0.99779249, 1.        , 0.99955908, 0.99955928,
#         0.99603349, 0.99647422, 1.        , 0.99779736, 1.        ])}

# %%
cvresults=cross_validate(model, X_new_test, cv=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-b5bfe8df3367> in <module>
# ----> 1 cvresults=cross_validate(model, X_new_test, cv=10)
#
# ~/.local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     230             return_times=True, return_estimator=return_estimator,
#     231             error_score=error_score)
# --> 232         for train, test in cv.split(X, y, groups))
#     233
#     234     zipped_scores = list(zip(*scores))
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#     919             # remaining jobs.
#     920             self._iterating = False
# --> 921             if self.dispatch_one_batch(iterator):
#     922                 self._iterating = self._original_iterator is not None
#     923
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~/.local/lib/python3.6/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/.local/lib/python3.6/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/.local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     512     try:
#     513         if y_train is None:
# --> 514             estimator.fit(X_train, **fit_params)
#     515         else:
#     516             estimator.fit(X_train, y_train, **fit_params)
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %%
# model.fit(X_new_train, Y_new_train)
# Out:
# Iteration 1, loss = 1.89715393
# Validation score: 0.515873
# Iteration 2, loss = 1.25315977
# Validation score: 0.797619
# Iteration 3, loss = 0.89023691
# Validation score: 0.896825
# Iteration 4, loss = 0.66762342
# Validation score: 0.952381
# Iteration 5, loss = 0.51851537
# Validation score: 0.940476
# Iteration 6, loss = 0.39837951
# Validation score: 0.964286
# Iteration 7, loss = 0.30572224
# Validation score: 0.972222
# Iteration 8, loss = 0.22984140
# Validation score: 0.980159
# Iteration 9, loss = 0.17808065
# Validation score: 0.984127
# Iteration 10, loss = 0.13961951
# Validation score: 0.976190
# Iteration 11, loss = 0.10894228
# Validation score: 0.992063
# Iteration 12, loss = 0.08178644
# Validation score: 0.988095
# Iteration 13, loss = 0.06403653
# Validation score: 0.984127
# Iteration 14, loss = 0.04894362
# Validation score: 0.992063
# Iteration 15, loss = 0.03818546
# Validation score: 0.992063
# Iteration 16, loss = 0.03084244
# Validation score: 0.988095
# Iteration 17, loss = 0.02502780
# Validation score: 0.988095
# Iteration 18, loss = 0.02092072
# Validation score: 1.000000
# Iteration 19, loss = 0.01804422
# Validation score: 0.996032
# Iteration 20, loss = 0.01577767
# Validation score: 0.992063
# Iteration 21, loss = 0.01381163
# Validation score: 1.000000
# Iteration 22, loss = 0.01255008
# Validation score: 1.000000
# Iteration 23, loss = 0.01196761
# Validation score: 0.996032
# Iteration 24, loss = 0.01060125
# Validation score: 1.000000
# Iteration 25, loss = 0.00987425
# Validation score: 0.996032
# Iteration 26, loss = 0.00911525
# Validation score: 1.000000
# Iteration 27, loss = 0.00836646
# Validation score: 0.996032
# Iteration 28, loss = 0.00765527
# Validation score: 0.992063
# Iteration 29, loss = 0.00760794
# Validation score: 0.996032
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(activation='tanh', alpha=0.01, batch_size=264, beta_1=0.9,
#               beta_2=0.999, early_stopping=True, epsilon=1e-08,
#               hidden_layer_sizes=(300,), learning_rate='adaptive',
#               learning_rate_init=0.001, max_iter=700, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=None, shuffle=True, solver='adam', tol=0.0001,
#               validation_fraction=0.1, verbose=True, warm_start=False)

# %%
Y_pred = model.predict(X_new_test)

# %%
cn = confusion_matrix(Y_pred,Y_new_test)

# %%
cn
# Out:
# array([[39,  0,  0,  0,  0,  0,  0],
#        [ 0, 57,  0,  0,  0,  0,  0],
#        [ 0,  0, 37,  0,  0,  0,  0],
#        [ 0,  0,  0, 39,  0,  0,  0],
#        [ 0,  0,  0,  0, 38,  0,  0],
#        [ 0,  0,  0,  0,  0, 33,  0],
#        [ 0,  1,  0,  0,  0,  0, 36]])
